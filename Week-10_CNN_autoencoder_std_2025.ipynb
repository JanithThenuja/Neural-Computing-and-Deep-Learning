# %%
from tensorflow import keras
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist
import numpy as np

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %%
(x_train, _), (x_test, _) = mnist.load_data()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

n = 10  # how many records we will display
plt.figure(figsize=(20, 2))

for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ![image.png](attachment:7b66c461-7e86-42f8-8fa2-1cb11eaaaaa2.png)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, UpSampling2D, Reshape

# %%
print(x_train.min(), x_train.max())
# Out:
# 0 255

# %%
encode_model = Sequential()

############
# Encoding #
############

## FIRST SET OF LAYERS
# CONVOLUTIONAL LAYER
encode_model.add(Conv2D(filters=16, kernel_size=(3,3), input_shape=(28, 28, 1), activation='relu', padding='same'))
# POOLING LAYER
encode_model.add(MaxPool2D(pool_size=(2, 2),  padding='same'))

## SECOND SET OF LAYERS
# CONVOLUTIONAL LAYER
encode_model.add(Conv2D(filters=8, kernel_size=(3,3), activation = 'relu', padding='same'))
# POOLING LAYER
encode_model.add(MaxPool2D(pool_size=(2, 2), padding='same'))

encode_model.add(Flatten())
encode_model.add(Dense(7*7*8, activation="relu"))
encode_model.add(Dense(30, activation="relu"))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
############
# Decoding #
############
decode_model=Sequential()

decode_model.add(Dense(7*7*8,activation="relu", input_shape=(30,)))
decode_model.add(Reshape([7,7,8]))

# DeConv1
decode_model.add(Conv2D(filters=8, kernel_size=(3,3), activation='relu', padding='same'))
# Upsampling LAYER
decode_model.add(UpSampling2D((2, 2)))

# Deconv2
decode_model.add(Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same'))
# POOLING LAYER
decode_model.add(UpSampling2D((2, 2)))

decode_model.add(Conv2D(filters=1, kernel_size=(3,3), activation='sigmoid', padding='same'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
autoencoder = Sequential([encode_model, decode_model])

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
autoencoder.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_3 (Sequential)       │ (None, 30)             │       167,166 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_4 (Sequential)       │ (None, 28, 28, 1)      │        14,049 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 181,215 (707.87 KB)
#  Trainable params: 181,215 (707.87 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras import models

# %%
autoencoder.save('Conv_autoencoder.keras')

# %%
encode_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 28, 28, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 14, 14, 8)      │         1,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 7, 7, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 392)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 392)            │       154,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 30)             │        11,790 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 167,166 (652.99 KB)
#  Trainable params: 167,166 (652.99 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
decode_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 392)            │        12,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 7, 7, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 7, 7, 8)        │           584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 14, 14, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_3 (UpSampling2D)  │ (None, 28, 28, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 28, 28, 1)      │           145 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,049 (54.88 KB)
#  Trainable params: 14,049 (54.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print(x_train.min(), x_train.max())
# Out:
# 0 255

# %%
x_train = x_train.reshape(60000,28,28,1).astype('float32') / 255.
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
x_test = x_test.reshape(10000, 28, 28, 1).astype('float32') / 255.
x_test.shape
# Out:
# (10000, 28, 28, 1)

# %%
# Train the model

history = autoencoder.fit(x=x_train, y=x_train,  epochs=43, batch_size=128, shuffle=True, verbose=1, validation_data=(x_test, x_test))
# Out:
# Epoch 1/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.7994 - loss: 0.2138 - val_accuracy: 0.8063 - val_loss: 0.1323
# Epoch 2/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8082 - loss: 0.1242 - val_accuracy: 0.8084 - val_loss: 0.1163
# Epoch 3/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8099 - loss: 0.1148 - val_accuracy: 0.8093 - val_loss: 0.1108
# Epoch 4/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8106 - loss: 0.1105 - val_accuracy: 0.8102 - val_loss: 0.1076
# Epoch 5/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8110 - loss: 0.1076 - val_accuracy: 0.8109 - val_loss: 0.1051
# Epoch 6/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8114 - loss: 0.1052 - val_accuracy: 0.8112 - val_loss: 0.1030
# Epoch 7/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8117 - loss: 0.1035 - val_accuracy: 0.8110 - val_loss: 0.1014
# Epoch 8/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8119 - loss: 0.1021 - val_accuracy: 0.8111 - val_loss: 0.0999
# Epoch 9/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8121 - loss: 0.1008 - val_accuracy: 0.8115 - val_loss: 0.0995
# Epoch 10/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8122 - loss: 0.0999 - val_accuracy: 0.8113 - val_loss: 0.0981
# Epoch 11/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8124 - loss: 0.0990 - val_accuracy: 0.8115 - val_loss: 0.0975
# Epoch 12/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8125 - loss: 0.0982 - val_accuracy: 0.8115 - val_loss: 0.0968
# Epoch 13/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8126 - loss: 0.0976 - val_accuracy: 0.8120 - val_loss: 0.0962
# Epoch 14/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8126 - loss: 0.0970 - val_accuracy: 0.8118 - val_loss: 0.0958
# Epoch 15/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8127 - loss: 0.0964 - val_accuracy: 0.8121 - val_loss: 0.0953
# Epoch 16/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8128 - loss: 0.0959 - val_accuracy: 0.8123 - val_loss: 0.0950
# Epoch 17/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8129 - loss: 0.0955 - val_accuracy: 0.8119 - val_loss: 0.0943
# Epoch 18/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8129 - loss: 0.0951 - val_accuracy: 0.8120 - val_loss: 0.0941
# Epoch 19/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8130 - loss: 0.0947 - val_accuracy: 0.8121 - val_loss: 0.0937
# Epoch 20/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8130 - loss: 0.0944 - val_accuracy: 0.8124 - val_loss: 0.0935
# Epoch 21/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8131 - loss: 0.0941 - val_accuracy: 0.8122 - val_loss: 0.0927
# Epoch 22/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8131 - loss: 0.0937 - val_accuracy: 0.8121 - val_loss: 0.0931
# Epoch 23/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8131 - loss: 0.0935 - val_accuracy: 0.8120 - val_loss: 0.0929
# Epoch 24/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8132 - loss: 0.0933 - val_accuracy: 0.8120 - val_loss: 0.0925
# Epoch 25/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8132 - loss: 0.0930 - val_accuracy: 0.8123 - val_loss: 0.0919
# Epoch 26/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8132 - loss: 0.0927 - val_accuracy: 0.8124 - val_loss: 0.0918
# Epoch 27/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8133 - loss: 0.0926 - val_accuracy: 0.8124 - val_loss: 0.0916
# Epoch 28/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8133 - loss: 0.0924 - val_accuracy: 0.8125 - val_loss: 0.0913
# Epoch 29/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8133 - loss: 0.0922 - val_accuracy: 0.8124 - val_loss: 0.0910
# Epoch 30/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8133 - loss: 0.0921 - val_accuracy: 0.8124 - val_loss: 0.0912
# Epoch 31/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8133 - loss: 0.0918 - val_accuracy: 0.8125 - val_loss: 0.0912
# Epoch 32/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8134 - loss: 0.0917 - val_accuracy: 0.8125 - val_loss: 0.0906
# Epoch 33/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8134 - loss: 0.0916 - val_accuracy: 0.8122 - val_loss: 0.0910
# Epoch 34/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8134 - loss: 0.0914 - val_accuracy: 0.8127 - val_loss: 0.0908
# Epoch 35/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8134 - loss: 0.0914 - val_accuracy: 0.8125 - val_loss: 0.0904
# Epoch 36/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8134 - loss: 0.0912 - val_accuracy: 0.8122 - val_loss: 0.0909
# Epoch 37/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8134 - loss: 0.0911 - val_accuracy: 0.8124 - val_loss: 0.0904
# Epoch 38/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8135 - loss: 0.0910 - val_accuracy: 0.8123 - val_loss: 0.0904
# Epoch 39/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8135 - loss: 0.0909 - val_accuracy: 0.8124 - val_loss: 0.0900
# Epoch 40/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8135 - loss: 0.0908 - val_accuracy: 0.8124 - val_loss: 0.0899
# Epoch 41/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8135 - loss: 0.0907 - val_accuracy: 0.8127 - val_loss: 0.0899
# Epoch 42/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8135 - loss: 0.0906 - val_accuracy: 0.8126 - val_loss: 0.0895
# Epoch 43/43
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8135 - loss: 0.0905 - val_accuracy: 0.8125 - val_loss: 0.0896

# %%
import matplotlib.pyplot as plt

# %%
print(x_train.min(), x_train.max())
# Out:
# 0.0 1.0

# %%
losses = history.history['loss']
losses_val = history.history['val_loss']
epochs = range(1, len(losses) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, losses, 'o-', label='Training loss')
plt.plot(epochs, losses_val, '-', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss function - binary_crossentropy')
plt.legend()
plt.show()

# %%
accuracy_array = history.history['accuracy']
val_accuracy_array = history.history['val_accuracy']
epochs = range(1, len(accuracy_array) + 1)

plt.figure(num=1, figsize=(14,6))
plt.plot(epochs, accuracy_array, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy_array, 'b', label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
losses = history.history['loss']
losses_val = history.history['val_loss']
epochs = range(1, len(losses) + 1)

import matplotlib.pyplot as plt

plt.figure(figsize=(15,7))
plt.plot(epochs, losses, 'o-', label='Training loss')
plt.plot(epochs, losses_val, '-', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (Reconstruction Error)')
plt.legend()
plt.show()

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10

plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28,28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i+1+n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10

plt.figure(figsize=(18, 5))   # changed size

for i in range(n):
    # ORIGINAL
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='viridis')   # changed color
    plt.title("Original", fontsize=10)
    plt.axis('off')

    # RECONSTRUCTED
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='magma')  # different color
    plt.title("Reconstructed", fontsize=10)
    plt.axis('off')

plt.suptitle("Autoencoder Results: Original vs Reconstructed", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ![image.png](attachment:f51e6fad-c8b0-48ee-b841-08b51142fe9c.png)

# %%
# optimizer is not so good,
# epoch number should be edded

# %% [markdown]
# ## Lab Logbook requirement:
#
# 1) Copy the autoencoder model and train it with epochs=Z+40,
# where your SID is: XXXXXXZ
# Leave other parameters the same as in Task 2.
#
# 2) Please only add to your Lab Logbook print-screens of:
# - Table of your model autoencoder.summary()
# - Code of your autoencoder.fit()
# - Accuracy detailed graph
# - Document the plot of the decoded images for task 2. Change the colour, appearance, and shape of the plot according to your own choice (see plt.figure() parameters).
#
#
# NOTE: DON'T FORGET TO SAVE AND BACK UP YOUR COMPLETED JUPYTER NOTEBOOK AND LAB LOGBOOK ON GITHUB OR ONEDRIVE.

# %%
# autoencoder_2 = models.load_model('Conv_autoencoder.keras')

# %%
# history_2 =

# %%
#
#
#
